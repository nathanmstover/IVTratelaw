# %%
using Pkg
#Activate TOML file in file tree. This installs the relevant packages specified for this project. This will take a long time the first time you run this. 
Pkg.activate("IE")
#Compile functions stored in modules
include("./modules/IE_rates_and_errors.jl")
#Adjust notebook cell width
display("text/html", "<style>.container { width:80% !important; }</style>")
# Out:
#   Activating project at `~/Documents/UROP/TASEP/data_processing/IE`
# <style>.container { width:80% !important; }</style>

# %%
datafileivt = "Data/EGFP/EGFPExperimentIE_Conditions.csv"
generate_rate_uncertainty(datafileivt, "EGFP/EFGP_processeddata_newfunction_V8")
# Out:
# Existing file renamed to: /Users/juliechen/Documents/UROP/TASEP/data_processing/output/EGFP/EFGP_processeddata_newfunction_V8_24-07-16.csv
# "/Users/juliechen/Documents/UROP/TASEP/data_processing/output/EGFP/EFGP_processeddata_newfunction_V8.csv"

# %%
plot_all_replicates(1, datafileivt)

# %%
plot_all_replicates_all_conditions(datafileivt)

# %%
bar_rates_all_repl(1, datafileivt)

# %%
bar_rates_all_repl_all_cond(datafileivt)
