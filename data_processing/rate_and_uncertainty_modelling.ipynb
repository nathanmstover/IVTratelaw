# %%
using Pkg
#Activate TOML file in file tree. This installs the relevant packages specified for this project. This will take a long time the first time you run this. 
Pkg.activate("IE")
#Compile functions stored in modules
include("./modules/IE_rates_and_errors.jl")
#Adjust notebook cell width
display("text/html", "<style>.container { width:80% !important; }</style>")
# Out:
#   Activating project at `c:\Users\chemegrad202\OneDrive - Massachusetts Institute of Technology\Documents\PhD_research\Braatz_Lab\TASEP\data_processing\IE`
#    Resolving package versions...
#   No Changes to `C:\Users\chemegrad202\OneDrive - Massachusetts Institute of Technology\Documents\PhD_research\Braatz_Lab\TASEP\data_processing\IE\Project.toml`
#   No Changes to `C:\Users\chemegrad202\OneDrive - Massachusetts Institute of Technology\Documents\PhD_research\Braatz_Lab\TASEP\data_processing\IE\Manifest.toml`
# <style>.container { width:80% !important; }</style>

# %%
generate_rate_uncertainties(datafileivt, "EFGP_processeddata_newfunction_V4")
# Out:
# Existing file renamed to: c:\Users\chemegrad202\OneDrive - Massachusetts Institute of Technology\Documents\PhD_research\Braatz_Lab\TASEP\data_processing\output\EFGP_processeddata_newfunction_V4_24-07-15.csv
# "c:\\Users\\chemegrad202\\OneDrive - Massachusetts Institute of Technology\\Documents\\PhD_research\\Braatz_Lab\\TASEP\\data_processing\\output\\EFGP_processeddata_newfunction_V4.csv"

# %%
plot_all_replicates(1, filtered_data, 0.27)

# %%
plot_all_replicates_all_conditions(filtered_data, 0.27)

# %%
bar_rates_all_repl(1, filtered_data, 0.27)

# %%
bar_rates_all_repl_all_cond(filtered_data, 0.27)
