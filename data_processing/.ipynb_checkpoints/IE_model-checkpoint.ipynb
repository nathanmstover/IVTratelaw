# %%
using Pkg
Pkg.activate("IE")
using DataFrames
using Plots
using XLSX
using ColorSchemes
using Statistics
using LinearAlgebra

include("IE_Plotting.jl")
include("IE_Dataprocessing.jl")
include("IE_rate.jl")
