# %%
using Pkg
Pkg.activate("TASEP")
#Pkg.instantiate()
include("./modules/transcription.jl")
# Out:
#   Activating project at `C:\Users\ChemeGrad2021\Documents\Braatz Group\MRNA Synthesis\TASEP\TASEP`
# plotparametricellipse (generic function with 1 method)

# %%
flucfilename = "data_processing/output/Fluc/Fluc_PDS_V15_Nathan.csv"
N_all = 2078
N_plasmid = 4352
analyzekineticdata(flucfilename,N_all,N_plasmid,2)
# Out:
# got a residual of 26.899169004278697 at [1222.1680719017716, 51.316544666019055, 9.944674327732399] (returned FTOL_REACHED)
# Parameter estimates (including 95% confidence intervals)
# k_i    K_MD    α    k_e,eff  k_e,bp
# 1222.2  51.3  9.9  136.6  283930.4
# 1126.8  27.3  9.2  129.5  269038.0
# 1317.5  75.2  10.7  144.4  300040.7

# %%
fluc12filename = "data_processing/output/Dodecamer/Dodecamer_V3_Nathan.csv"
N_all = 12
N_plasmid = 29
analyzekineticdata(fluc12filename,N_all,N_plasmid,2,massDNAunits = false,npoints = 10000)
# Out:
# got a residual of 7.594723356395236e-30 at [1500.5229857467914, 49.99999999999999, 0.6659713494385263] (returned FTOL_REACHED)
# Parameter estimates (including 95% confidence intervals)
# k_i    K_MD    α    k_e,eff  k_e,bp
# 1500.5  50.0  0.7  -4492.2  -53906.4
# 1213.2  10.7  0.4  -20009.6  -240115.2
# 1787.8  89.2  0.9  -2063.5  -24761.6

# %%
covidfilename = "data_processing/output/COVID/COVID_PDS_V7_Nathan.csv"
N_all = 4243
N_plasmid = 6082
analyzekineticdata(covidfilename,N_all,N_plasmid,2)
# Out:
# got a residual of 0.0 at [1284.838961469154, 50.0, 19.692230354985412] (returned FTOL_REACHED)
# Parameter estimates (including 95% confidence intervals)
# k_i    K_MD    α    k_e,eff  k_e,bp
# 1284.8  50.0  19.7  68.7  291649.1
# 1130.0  10.9  16.4  59.8  253642.7
# 1439.6  89.2  23.0  80.4  341129.6

# %%
egfpfilename = "data_processing/output/EGFP/EGFP_PDS_V13_Nathan.csv"
N_all = 942
N_plasmid = 2782
analyzekineticdata(egfpfilename,N_all,N_plasmid,2)
# Out:
# got a residual of 8.558483347282078 at [2790.825965341172, 59.802617851090794, 15.107746060915439] (returned FTOL_REACHED)
# Parameter estimates (including 95% confidence intervals)
# k_i    K_MD    α    k_e,eff  k_e,bp
# 2790.8  59.8  15.1  197.8  186348.6
# 2441.8  22.3  12.5  169.0  159158.7
# 3139.7  97.3  17.8  236.4  222679.5
